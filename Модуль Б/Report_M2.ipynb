# %% [markdown]
# # Анализ количественных данных

# %% [markdown]
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 1. Анализ основных свойств данных
# - 1.1 Был выявлен расчет основных статестических характеристик данных.
#
# - 1.2 Был построен график плотности распределения для основных данных.
#
# - 1.3 Был выполнен программно корреляционный анализ между переменными.

# %% [markdown]
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 2. Поиск закономерностей и аномалий
# - 2.1 Были выявлены закономерности и аномалии.
#
# - 2.2 Был произведен кластерный анализ для поиска групп сходных объектов.
#
# - 2.3 Были найдены временные тренды в данных.

# %% [markdown]
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 3. Математические методы анализа данных
# - 3.1 Был выполнен математический анализ данных.
#
# - 3.2 Математический анализ данных был выполнен программно.

# %% [markdown]
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 4. Подготовка аналитической справки
# - 4.1 Была создана анлитическая справка.
#
# - 4.2 Аналитическая справка охватывает результаты всей проделанной работы.

# %% [markdown]
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 5. Визуализация данных
# - 5.1 Был построен график динамики.
#
# - 5.2 Все элементы присутствуют в построенном дашборде.
#
# - 5.3 Визуализация дашборда наглядно отражает рост или снижение показателей.

# %% [markdown]
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 6. Проектирование информационно аналитических систем
# - 6.1 Были реализованны методы защиты данных, представленные в дашборде.
#
# - 6.2 Предусмотрена возможность настройки доступа к информации в соотвествии с ролями пользователей и их уровнем доступа.
#
# - 6.3 Интерфейс дашборда разработан по отраслевому стандарту.

# %% [markdown]
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________________
