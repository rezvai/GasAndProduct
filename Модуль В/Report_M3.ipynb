# %% [markdown]
# # Обработка и анализ текстовых данных

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 1. Предобработка данных
# - 1.1 Парсинг был выполнен с указаных веб ресурсов.
#
# - 1.2 Структура набора данных была сформулирована.
#
# - 1.3 Была выполнена очистка от HTML-тегов, специальных символов и лишних пробелов.
#
# - 1.4 Текст был приведен к нижнему регистру.
#
# - 1.5 Были удалены стоп-слова.
#
# - 1.6 Была проведена лемматизация.
#
# - 1.7 Задание было выполненно в полном объеме.

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 2. Построение и отбор признаков
# - 2.1 Были созданы числовые признаки на основе количества слов, символов.
#
# - 2.2 Был создан числовой признак на основе заспамленности.
#
# - 2.3 Был создан числовой признак на основе средняя длина слов/предложений.
#
# - 2.4 Была произведена кластеризация выделенных признаков.
#
# - 2.5 Была произведена классификация выделенных признаков.

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 3. Подготовка отчетов
# - 3.1 Был создан отчет о проделанной работе.
#
# - 3.2 Отчет охватывает результаты всей проделанной работы.

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 4. Визуальный анализ статистики текстовых признаков
# - 4.1 Построена таблица с признаком и частотой встречаемости.
#
# - 4.2 Построена гистограмма распределения текстовых признаков.
#
# - 4.3 Построена диаграмма распределения текстовых признаков.

# %% [markdown]
# _________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
