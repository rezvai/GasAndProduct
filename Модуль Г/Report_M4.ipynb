# %% [markdown]
# # Сетевой анализ данных

# %% [markdown]
# _____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 1. Построение графа связей
# - 1.1 Граф связей был построен.
#
# - 1.2 Граф связей дает возможность понять оптимальные пути транспортировки нефти.
#
# - 1.3 Были описаны основные метрики полученного графа.

# %% [markdown]
# _____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 2. Сетевой анализ данных
# - 2.1 Был проведен сетевой анализ данных для определения наиболее вадных узлов сети.
#
# - 2.2 Была произведена оптимизация путей транспортировки.
#
# - 2.3 Были выявленны узкие места, произведенна оптимизация.

# %% [markdown]
# _____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 3. Подготовка отчета
# - 3.1 Был подготовлен отчет о проделанной работе.
#
# - 3.2 Отчет охватывает все результаты проделанной работы.

# %% [markdown]
# _____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 4. Описание рекомендаций
# - 4.1 Были даны рекомендации по улучшению взаимодействия и привлечению пользователей.

# %% [markdown]
# _____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## 5. Проектирование информационно-аналитических систем
# - 5.1 Были реализованы методы защиты данных в построенном графе.
#
# - 5.2 Был выполнен мониторинг данных, отслеживание измененеий.
#
# - 5.3 Были описаны функциональные требования к интерактивному графу.

# %% [markdown]
# _____________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________
